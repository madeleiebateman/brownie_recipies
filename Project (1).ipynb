# %% [markdown]
# # Project

# %% [markdown]
# You're going to build a streamlit app like the [Westminster Directory app](https://westminster-directory.streamlit.app/) or [Recipe app](https://allrecipes.streamlit.app/) I showed in class.
#
# You are expected to use what we have learned in class:
#
# - numpy
# - pandas
# - matplotlib
# - regualr expression
# - web scraping
# - streamlit
# - etc..

# %% [markdown]
# ## Step 1: Project Idea and Plan
#
# You need to submit your project idea and plan by the class time on 4/22 Tuesday next week.
#
# Here are some example ideas:
#
# - Weather Data: scrapes weather data from a weather website (e.g., Weather.com) for a specific location. Extract information such as temperature, humidity, wind speed, and weather condition.
#
# - Job Listings: scrapes job listings from a job search website (e.g., Indeed.com or LinkedIn). Gather details such as job title, company name, location, and job description.
#
# - News Headlines: scrapes headlines from a news website (e.g., CNN.com or BBC.com). Extract the title of the article, publication date, and a brief summary.
#
# - Wikipedia on a specific topic.
#
# - Movie: scrapes information about movies from a movie database website (e.g., IMDb or Rotten Tomatoes). Gather details such as movie title, release year, genre, cast, and ratings.
#
# - Some professional websites related to your major.
#
# Here are some example plans:
#
# - Recipe app: Provide a functionality to choose recipes at the selected range of calories.
#
# - Job app: Provide the trend of the programming languages in the market.
#
# - Movie: Provide the trend of the review rating. Analyze the sentiment and genre information.
#
# - News: Analyze how hot a topic is.
#
# ## Step 2: Project
#
# You have about 2-3 weeks to build your project in following steps:
#
# 1. Exploring and making a project idea and plan.
#
# 2. Scraping the data.
#
# 3. Desiging and drafting the interface and functionality of an app.
#
# 4. Building the streamlit app in your local laptop.
#
# 5. Publishing it in public via github and streamlit cloud.

# %%
import requests
from bs4 import BeautifulSoup
import re
import numpy as np
import pandas as pd

# %%
recipes = []
URL = "https://www.americastestkitchen.com/search?q=brownies"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")


results = soup.find('ul', class_ ="AlgoliaResults_grid__NXdqe")
recipe_urls = results.find_all('a', class_="ResultLink_resultLink__Duhpm")

for recipe_url in recipe_urls:
    
    recipe = []
    
    recipe_url = "https://www.americastestkitchen.com" + recipe_url['href']

    try:
        recipe_page = requests.get(recipe_url)
        recipe_soup = BeautifulSoup(recipe_page.content, "html.parser")
        
        name_recipe = recipe_soup.find('h1').text.strip()
        rating_recipe = recipe_soup.find('span', id="recipe-header-rating-score").text.strip()
        count_recipe = recipe_soup.find('span', id="recipe-header-rating-count").text.strip()
        
        ingredient_list = recipe_soup.find_all('div', class_ ="RecipeIngredient_controlCheckbox__HszPl")
        num_ingredients = len(ingredient_list)
        
        
        #time = recipe_soup.find_all ('span', class_="typography typography-module_base__PkumT typography-module_open-sm__6cWJa typography-module_proxima__HDZ4V")
 #=====       
        time_elements = recipe_soup.find_all('span', class_="typography typography-module_base__PkumT typography-module_open-sm__6cWJa typography-module_proxima__HDZ4V")

        for time_element in time_elements:
            

            time_text = time_element.text.strip()
    
            # Use a regex to capture the part before the comma (e.g., 2¾ hours)
            match = re.match(r'^[\d/]+(?:\s*\w+)?\s+hours?', time_text)
            if match:
                time = match.group(0)
                break  # Assuming the time is the first matching element
            else:
                time = None  # If no match found
 #======           
        recipe.append([name_recipe, rating_recipe, count_recipe, num_ingredients, time_text]) #calories_recipe])

    except:
        recipe.extend([None, None, None, None, None])        
    
    recipes.append(recipe[0])  
recipes
# Out:
# [['Ultimate Brookies', '4', '(37)', 21, '1¾ hours, plus 2 hours cooling'],
#  ['Ultimate Brookies', '4', '(37)', 21, '1¾ hours, plus 2 hours cooling'],
#  ["Millionaire's Shortbread",
#   '4.5',
#   '(842)',
#   11,
#   '1¾ hours, plus 1½ hours cooling'],
#  ["Millionaire's Shortbread",
#   '4.5',
#   '(842)',
#   11,
#   '1¾ hours, plus 1½ hours cooling'],
#  ['Ultimate Turtle Brownies',
#   '4.5',
#   '(18)',
#   19,
#   '1¾ hours, plus 1½ hours cooling and 2 hours chilling'],
#  ['Ultimate Turtle Brownies',
#   '4.5',
#   '(18)',
#   19,
#   '1¾ hours, plus 1½ hours cooling and 2 hours chilling'],
#  ['Lemon Bars', '4.5', '(134)', 11, '1½ hours, plus 2 hours cooling'],
#  ['Lemon Bars', '4.5', '(134)', 11, '1½ hours, plus 2 hours cooling'],
#  ['Chewy Brownies', '4', '(306)', 13, '1 hour, plus 2½ hours cooling'],
#  ['Chewy Brownies', '4', '(306)', 13, '1 hour, plus 2½ hours cooling'],
#  ['Strawberry Cheesecake Bars',
#   '4.5',
#   '(327)',
#   12,
#   '2¾ hours. plus 2½ hours cooling and 4 hours chilling'],
#  ['Strawberry Cheesecake Bars',
#   '4.5',
#   '(327)',
#   12,
#   '2¾ hours. plus 2½ hours cooling and 4 hours chilling'],
#  ['Lemon Cookie Bars', '4.5', '(138)', 14, '1¼ hours, plus 3 hours cooling'],
#  ['Lemon Cookie Bars', '4.5', '(138)', 14, '1¼ hours, plus 3 hours cooling'],
#  ['Browned Butter Blondies',
#   '4',
#   '(218)',
#   11,
#   '1¼ hours, plus 2 hours cooling'],
#  ['Browned Butter Blondies',
#   '4',
#   '(218)',
#   11,
#   '1¼ hours, plus 2 hours cooling'],
#  ['Vegan Brownies', '4.5', '(89)', 11, '55 minutes, plus 3 hours cooling'],
#  ['Vegan Brownies', '4.5', '(89)', 11, '55 minutes, plus 3 hours cooling'],
#  ['Ultranutty Pecan Bars',
#   '4.5',
#   '(389)',
#   11,
#   '1 hour, plus 1½ hours cooling'],
#  ['Ultranutty Pecan Bars',
#   '4.5',
#   '(389)',
#   11,
#   '1 hour, plus 1½ hours cooling'],
#  ['Chocolate Fudge',
#   '4',
#   '(191)',
#   7,
#   '45 minutes, plus 2 hours cooling and 2 hours chilling'],
#  ['Chocolate Fudge',
#   '4',
#   '(191)',
#   7,
#   '45 minutes, plus 2 hours cooling and 2 hours chilling'],
#  ['Cream Cheese Brownies',
#   '4.5',
#   '(115)',
#   12,
#   '1¼ hours, plus 2 hours cooling'],
#  ['Cream Cheese Brownies',
#   '4.5',
#   '(115)',
#   12,
#   '1¼ hours, plus 2 hours cooling'],
#  ['Crispy Rice Cereal Treats',
#   '4',
#   '(108)',
#   5,
#   '15 minutes, plus 1 hour setting'],
#  ['Crispy Rice Cereal Treats',
#   '4',
#   '(108)',
#   5,
#   '15 minutes, plus 1 hour setting'],
#  ['Key Lime Bars',
#   '4',
#   '(92)',
#   11,
#   '1¼ hours, plus 1 to 1½ hours cooling and 2 hours chilling'],
#  ['Key Lime Bars',
#   '4',
#   '(92)',
#   11,
#   '1¼ hours, plus 1 to 1½ hours cooling and 2 hours chilling'],
#  ['Classic Brownies', '4.5', '(81)', 9, '1¼ hours, plus 2 hours cooling'],
#  ['Classic Brownies', '4.5', '(81)', 9, '1¼ hours, plus 2 hours cooling'],
#  ['Chewy, Fudgy Triple Chocolate Brownies',
#   '4',
#   '(112)',
#   9,
#   '1 hour, plus 2 hours cooling'],
#  ['Chewy, Fudgy Triple Chocolate Brownies',
#   '4',
#   '(112)',
#   9,
#   '1 hour, plus 2 hours cooling'],
#  ["S'mores Bars", '4.5', '(196)', 8, '1½ hours, plus 4 hours cooling'],
#  ["S'mores Bars", '4.5', '(196)', 8, '1½ hours, plus 4 hours cooling'],
#  ['Gooey Butter Cake Bars',
#   '4',
#   '(81)',
#   10,
#   '1¾ hours, plus 3½ hours cooling'],
#  ['Gooey Butter Cake Bars',
#   '4',
#   '(81)',
#   10,
#   '1¾ hours, plus 3½ hours cooling'],
#  ['Blondies', '4', '(113)', 9, '1¼ hours, plus 20 minutes cooling'],
#  ['Blondies', '4', '(113)', 9, '1¼ hours, plus 20 minutes cooling'],
#  ['Cheesecake Bars',
#   '4.5',
#   '(61)',
#   11,
#   '1¾ hours, plus 2 hours cooling, and 3 hours chilling, and 4 hours thawing'],
#  ['Cheesecake Bars',
#   '4.5',
#   '(61)',
#   11,
#   '1¾ hours, plus 2 hours cooling, and 3 hours chilling, and 4 hours thawing'],
#  ['Easy Chocolate Chunk Brownies',
#   '4',
#   '(77)',
#   11,
#   '1 hour, plus 2½ hours cooling'],
#  ['Easy Chocolate Chunk Brownies',
#   '4',
#   '(77)',
#   11,
#   '1 hour, plus 2½ hours cooling'],
#  ['Scotcheroos', '4.5', '(139)', 8, '1 hour, plus 2 hours cooling'],
#  ['Scotcheroos', '4.5', '(139)', 8, '1 hour, plus 2 hours cooling'],
#  ['Nanaimo Bars',
#   '4',
#   '(36)',
#   16,
#   '40 minutes, plus 2½ hours chilling, plus 20 minutes tempering'],
#  ['Nanaimo Bars',
#   '4',
#   '(36)',
#   16,
#   '40 minutes, plus 2½ hours chilling, plus 20 minutes tempering'],
#  ['Chocolate Ganache-Filled Brownies',
#   '4.5',
#   '(73)',
#   12,
#   '1¾ hours, plus 5¼ hours cooling'],
#  ['Chocolate Ganache-Filled Brownies',
#   '4.5',
#   '(73)',
#   12,
#   '1¾ hours, plus 5¼ hours cooling'],
#  ['Raspberry Streusel Bars',
#   '4.5',
#   '(57)',
#   10,
#   '1¼ hours, plus 2 hours cooling'],
#  ['Raspberry Streusel Bars',
#   '4.5',
#   '(57)',
#   10,
#   '1¼ hours, plus 2 hours cooling'],
#  ['Quicker Turtle Brownies',
#   '4',
#   '(4)',
#   11,
#   '1¼ hours, plus 1½ hours cooling'],
#  ['Quicker Turtle Brownies',
#   '4',
#   '(4)',
#   11,
#   '1¼ hours, plus 1½ hours cooling'],
#  ['Gluten-Free Lemon Bars',
#   '4',
#   '(13)',
#   12,
#   '1½ hours, plus 2½ hours cooling'],
#  ['Gluten-Free Lemon Bars',
#   '4',
#   '(13)',
#   12,
#   '1½ hours, plus 2½ hours cooling'],
#  ['Congo Bars', '4.5', '(36)', 10, '1¼ hours, plus 20 minutes cooling'],
#  ['Congo Bars', '4.5', '(36)', 10, '1¼ hours, plus 20 minutes cooling'],
#  ['Gluten-Free Fudgy Brownies',
#   '4.5',
#   '(24)',
#   9,
#   '1¼ hours, plus 30 minutes resting and 20 minutes cooling'],
#  ['Gluten-Free Fudgy Brownies',
#   '4.5',
#   '(24)',
#   9,
#   '1¼ hours, plus 30 minutes resting and 20 minutes cooling'],
#  ['Triple-Chocolate Espresso Brownies',
#   '4.5',
#   '(39)',
#   10,
#   '1 hour, plus 2 hours cooling'],
#  ['Triple-Chocolate Espresso Brownies',
#   '4.5',
#   '(39)',
#   10,
#   '1 hour, plus 2 hours cooling'],
#  ['Crunchy Granola Bars',
#   '4.5',
#   '(36)',
#   8,
#   '1¾ hours, plus 20 minutes cooling'],
#  ['Crunchy Granola Bars',
#   '4.5',
#   '(36)',
#   8,
#   '1¾ hours, plus 20 minutes cooling'],
#  ['Chocolate Peanut Butter Fudge',
#   '5',
#   '(30)',
#   8,
#   '40 minutes, plus 2 hours cooling and 2 hours chilling'],
#  ['Chocolate Peanut Butter Fudge',
#   '5',
#   '(30)',
#   8,
#   '40 minutes, plus 2 hours cooling and 2 hours chilling'],
#  ['Cast Iron Brownie', '4', '(54)', 12, '50 minutes, plus 35 minutes cooling'],
#  ['Cast Iron Brownie', '4', '(54)', 12, '50 minutes, plus 35 minutes cooling'],
#  ['Basic Brownies', '4.5', '(27)', 8, '50 minutes, plus 2 hours cooling'],
#  ['Basic Brownies', '4.5', '(27)', 8, '50 minutes, plus 2 hours cooling'],
#  ['Blondie Bites',
#   '4',
#   '(7)',
#   8,
#   '“It has a fudgy texture that’s nice like a brownie.” —Celia, recipe tester, age 12'],
#  ['Blondie Bites',
#   '4',
#   '(7)',
#   8,
#   '“It has a fudgy texture that’s nice like a brownie.” —Celia, recipe tester, age 12'],
#  ['Almond-Cherry-Coconut Granola Bars',
#   '5',
#   '(10)',
#   10,
#   '1½ hours plus 20 minutes cooling'],
#  ['Almond-Cherry-Coconut Granola Bars',
#   '5',
#   '(10)',
#   10,
#   '1½ hours plus 20 minutes cooling']]

# %%
brownie_recipes = pd.DataFrame(recipes, columns=["Title", "Review Rating", "Review Count", "Ingredient Count", "Time"])
brownie_recipes.head()
# Out:
#                       Title Review Rating Review Count  Ingredient Count  \
# 0         Ultimate Brookies             4         (37)                21
# 1         Ultimate Brookies             4         (37)                21
# 2  Millionaire's Shortbread           4.5        (842)                11
# 3  Millionaire's Shortbread           4.5        (842)                11
# 4  Ultimate Turtle Brownies           4.5         (18)                19
#
#                                                 Time
# 0                     1¾ hours, plus 2 hours cooling
# 1                     1¾ hours, plus 2 hours cooling
# 2                    1¾ hours, plus 1½ hours cooling
# 3                    1¾ hours, plus 1½ hours cooling
# 4  1¾ hours, plus 1½ hours cooling and 2 hours ch...

# %%
brownie_recipes = brownie_recipes.drop_duplicates()
brownie_recipes.reset_index(drop=True, inplace=True)
brownie_recipes.head()
# Out:
#                       Title Review Rating Review Count  Ingredient Count  \
# 0         Ultimate Brookies             4         (37)                21
# 1  Millionaire's Shortbread           4.5        (842)                11
# 2  Ultimate Turtle Brownies           4.5         (18)                19
# 3                Lemon Bars           4.5        (134)                11
# 4            Chewy Brownies             4        (306)                13
#
#                                                 Time
# 0                     1¾ hours, plus 2 hours cooling
# 1                    1¾ hours, plus 1½ hours cooling
# 2  1¾ hours, plus 1½ hours cooling and 2 hours ch...
# 3                     1½ hours, plus 2 hours cooling
# 4                      1 hour, plus 2½ hours cooling

# %%
brownie_recipes.dtypes
# Out:
# Title               object
# Review Rating       object
# Review Count        object
# Ingredient Count     int64
# Time                object
# dtype: object

# %%
brownie_recipes['Review Rating'] = brownie_recipes['Review Rating'].astype('float')
brownie_recipes.dtypes
# Out:
# Title                object
# Review Rating       float64
# Review Count         object
# Ingredient Count      int64
# Time                 object
# dtype: object

# %%
brownie_recipes['Review Count'] = (
    brownie_recipes['Review Count']
    .astype(str)
    .str.replace(r'[(),]', '', regex=True)
    .replace('', np.nan)  
    .astype('Int64')      
)

brownie_recipes.dtypes
# Out:
# Title                object
# Review Rating       float64
# Review Count          Int64
# Ingredient Count      int64
# Time                 object
# dtype: object

# %%
brownie_recipes
# Out:
#                                      Title  Review Rating  Review Count  \
# 0                        Ultimate Brookies            4.0            37
# 1                 Millionaire's Shortbread            4.5           842
# 2                 Ultimate Turtle Brownies            4.5            18
# 3                               Lemon Bars            4.5           134
# 4                           Chewy Brownies            4.0           306
# 5               Strawberry Cheesecake Bars            4.5           327
# 6                        Lemon Cookie Bars            4.5           138
# 7                  Browned Butter Blondies            4.0           218
# 8                           Vegan Brownies            4.5            89
# 9                    Ultranutty Pecan Bars            4.5           389
# 10                         Chocolate Fudge            4.0           191
# 11                   Cream Cheese Brownies            4.5           115
# 12               Crispy Rice Cereal Treats            4.0           108
# 13                           Key Lime Bars            4.0            92
# 14                        Classic Brownies            4.5            81
# 15  Chewy, Fudgy Triple Chocolate Brownies            4.0           112
# 16                            S'mores Bars            4.5           196
# 17                  Gooey Butter Cake Bars            4.0            81
# 18                                Blondies            4.0           113
# 19                         Cheesecake Bars            4.5            61
# 20           Easy Chocolate Chunk Brownies            4.0            77
# 21                             Scotcheroos            4.5           139
# 22                            Nanaimo Bars            4.0            36
# 23       Chocolate Ganache-Filled Brownies            4.5            73
# 24                 Raspberry Streusel Bars            4.5            57
# 25                 Quicker Turtle Brownies            4.0             4
# 26                  Gluten-Free Lemon Bars            4.0            13
# 27                              Congo Bars            4.5            36
# 28              Gluten-Free Fudgy Brownies            4.5            24
# 29      Triple-Chocolate Espresso Brownies            4.5            39
# 30                    Crunchy Granola Bars            4.5            36
# 31           Chocolate Peanut Butter Fudge            5.0            30
# 32                       Cast Iron Brownie            4.0            54
# 33                          Basic Brownies            4.5            27
# 34                           Blondie Bites            4.0             7
# 35      Almond-Cherry-Coconut Granola Bars            5.0            10
#
#     Ingredient Count                                               Time
# 0                 21                     1¾ hours, plus 2 hours cooling
# 1                 11                    1¾ hours, plus 1½ hours cooling
# 2                 19  1¾ hours, plus 1½ hours cooling and 2 hours ch...
# 3                 11                     1½ hours, plus 2 hours cooling
# 4                 13                      1 hour, plus 2½ hours cooling
# 5                 12  2¾ hours. plus 2½ hours cooling and 4 hours ch...
# 6                 14                     1¼ hours, plus 3 hours cooling
# 7                 11                     1¼ hours, plus 2 hours cooling
# 8                 11                   55 minutes, plus 3 hours cooling
# 9                 11                      1 hour, plus 1½ hours cooling
# 10                 7  45 minutes, plus 2 hours cooling and 2 hours c...
# 11                12                     1¼ hours, plus 2 hours cooling
# 12                 5                    15 minutes, plus 1 hour setting
# 13                11  1¼ hours, plus 1 to 1½ hours cooling and 2 hou...
# 14                 9                     1¼ hours, plus 2 hours cooling
# 15                 9                       1 hour, plus 2 hours cooling
# 16                 8                     1½ hours, plus 4 hours cooling
# 17                10                    1¾ hours, plus 3½ hours cooling
# 18                 9                  1¼ hours, plus 20 minutes cooling
# 19                11  1¾ hours, plus 2 hours cooling, and 3 hours ch...
# 20                11                      1 hour, plus 2½ hours cooling
# 21                 8                       1 hour, plus 2 hours cooling
# 22                16  40 minutes, plus 2½ hours chilling, plus 20 mi...
# 23                12                    1¾ hours, plus 5¼ hours cooling
# 24                10                     1¼ hours, plus 2 hours cooling
# 25                11                    1¼ hours, plus 1½ hours cooling
# 26                12                    1½ hours, plus 2½ hours cooling
# 27                10                  1¼ hours, plus 20 minutes cooling
# 28                 9  1¼ hours, plus 30 minutes resting and 20 minut...
# 29                10                       1 hour, plus 2 hours cooling
# 30                 8                  1¾ hours, plus 20 minutes cooling
# 31                 8  40 minutes, plus 2 hours cooling and 2 hours c...
# 32                12                50 minutes, plus 35 minutes cooling
# 33                 8                   50 minutes, plus 2 hours cooling
# 34                 8  “It has a fudgy texture that’s nice like a bro...
# 35                10                   1½ hours plus 20 minutes cooling

# %%
test_string = '2¾ hours, plus 2½ hours cooling'

# Test the regex pattern
result = re.match(r'(\d{1,2}[½¼¾]?)\s?\w+,\s*plus\s*(\d{1,2}[½¼¾]?)\s\w+', test_string)

# If the match succeeds, print the extracted values
if result:
    print(result.groups())  # Should print the bake and cool times
else:
    print("No match found")
# Out:
# ('2¾', '2½')

# %%
brownie_recipes[['Bake and Prep Time','Cool Time']]=brownie_recipes['Time'].str.extract(r'(\d{1,2}[½¼¾]?)\s?\w+,?\.?\s*plus\s*(\d{1,2}[½¼¾]?)\s\w+')
brownie_recipes
# Out:
#                                      Title  Review Rating  Review Count  \
# 0                        Ultimate Brookies            4.0            37
# 1                 Millionaire's Shortbread            4.5           842
# 2                 Ultimate Turtle Brownies            4.5            18
# 3                               Lemon Bars            4.5           134
# 4                           Chewy Brownies            4.0           306
# 5               Strawberry Cheesecake Bars            4.5           327
# 6                        Lemon Cookie Bars            4.5           138
# 7                  Browned Butter Blondies            4.0           218
# 8                           Vegan Brownies            4.5            89
# 9                    Ultranutty Pecan Bars            4.5           389
# 10                         Chocolate Fudge            4.0           191
# 11                   Cream Cheese Brownies            4.5           115
# 12               Crispy Rice Cereal Treats            4.0           108
# 13                           Key Lime Bars            4.0            92
# 14                        Classic Brownies            4.5            81
# 15  Chewy, Fudgy Triple Chocolate Brownies            4.0           112
# 16                            S'mores Bars            4.5           196
# 17                  Gooey Butter Cake Bars            4.0            81
# 18                                Blondies            4.0           113
# 19                         Cheesecake Bars            4.5            61
# 20           Easy Chocolate Chunk Brownies            4.0            77
# 21                             Scotcheroos            4.5           139
# 22                            Nanaimo Bars            4.0            36
# 23       Chocolate Ganache-Filled Brownies            4.5            73
# 24                 Raspberry Streusel Bars            4.5            57
# 25                 Quicker Turtle Brownies            4.0             4
# 26                  Gluten-Free Lemon Bars            4.0            13
# 27                              Congo Bars            4.5            36
# 28              Gluten-Free Fudgy Brownies            4.5            24
# 29      Triple-Chocolate Espresso Brownies            4.5            39
# 30                    Crunchy Granola Bars            4.5            36
# 31           Chocolate Peanut Butter Fudge            5.0            30
# 32                       Cast Iron Brownie            4.0            54
# 33                          Basic Brownies            4.5            27
# 34                           Blondie Bites            4.0             7
# 35      Almond-Cherry-Coconut Granola Bars            5.0            10
#
#     Ingredient Count                                               Time  \
# 0                 21                     1¾ hours, plus 2 hours cooling
# 1                 11                    1¾ hours, plus 1½ hours cooling
# 2                 19  1¾ hours, plus 1½ hours cooling and 2 hours ch...
# 3                 11                     1½ hours, plus 2 hours cooling
# 4                 13                      1 hour, plus 2½ hours cooling
# 5                 12  2¾ hours. plus 2½ hours cooling and 4 hours ch...
# 6                 14                     1¼ hours, plus 3 hours cooling
# 7                 11                     1¼ hours, plus 2 hours cooling
# 8                 11                   55 minutes, plus 3 hours cooling
# 9                 11                      1 hour, plus 1½ hours cooling
# 10                 7  45 minutes, plus 2 hours cooling and 2 hours c...
# 11                12                     1¼ hours, plus 2 hours cooling
# 12                 5                    15 minutes, plus 1 hour setting
# 13                11  1¼ hours, plus 1 to 1½ hours cooling and 2 hou...
# 14                 9                     1¼ hours, plus 2 hours cooling
# 15                 9                       1 hour, plus 2 hours cooling
# 16                 8                     1½ hours, plus 4 hours cooling
# 17                10                    1¾ hours, plus 3½ hours cooling
# 18                 9                  1¼ hours, plus 20 minutes cooling
# 19                11  1¾ hours, plus 2 hours cooling, and 3 hours ch...
# 20                11                      1 hour, plus 2½ hours cooling
# 21                 8                       1 hour, plus 2 hours cooling
# 22                16  40 minutes, plus 2½ hours chilling, plus 20 mi...
# 23                12                    1¾ hours, plus 5¼ hours cooling
# 24                10                     1¼ hours, plus 2 hours cooling
# 25                11                    1¼ hours, plus 1½ hours cooling
# 26                12                    1½ hours, plus 2½ hours cooling
# 27                10                  1¼ hours, plus 20 minutes cooling
# 28                 9  1¼ hours, plus 30 minutes resting and 20 minut...
# 29                10                       1 hour, plus 2 hours cooling
# 30                 8                  1¾ hours, plus 20 minutes cooling
# 31                 8  40 minutes, plus 2 hours cooling and 2 hours c...
# 32                12                50 minutes, plus 35 minutes cooling
# 33                 8                   50 minutes, plus 2 hours cooling
# 34                 8  “It has a fudgy texture that’s nice like a bro...
# 35                10                   1½ hours plus 20 minutes cooling
#
#    Bake and Prep Time Cool Time
# 0                  1¾         2
# 1                  1¾        1½
# 2                  1¾        1½
# 3                  1½         2
# 4                   1        2½
# 5                  2¾        2½
# 6                  1¼         3
# 7                  1¼         2
# 8                  55         3
# 9                   1        1½
# 10                 45         2
# 11                 1¼         2
# 12                 15         1
# 13                 1¼         1
# 14                 1¼         2
# 15                  1         2
# 16                 1½         4
# 17                 1¾        3½
# 18                 1¼        20
# 19                 1¾         2
# 20                  1        2½
# 21                  1         2
# 22                 40        2½
# 23                 1¾        5¼
# 24                 1¼         2
# 25                 1¼        1½
# 26                 1½        2½
# 27                 1¼        20
# 28                 1¼        30
# 29                  1         2
# 30                 1¾        20
# 31                 40         2
# 32                 50        35
# 33                 50         2
# 34                NaN       NaN
# 35                 1½        20

# %%
brownie_recipes = brownie_recipes.drop(columns=['Time'])
brownie_recipes
# Out:
#                                      Title  Review Rating  Review Count  \
# 0                        Ultimate Brookies            4.0            37
# 1                 Millionaire's Shortbread            4.5           842
# 2                 Ultimate Turtle Brownies            4.5            18
# 3                               Lemon Bars            4.5           134
# 4                           Chewy Brownies            4.0           306
# 5               Strawberry Cheesecake Bars            4.5           327
# 6                        Lemon Cookie Bars            4.5           138
# 7                  Browned Butter Blondies            4.0           218
# 8                           Vegan Brownies            4.5            89
# 9                    Ultranutty Pecan Bars            4.5           389
# 10                         Chocolate Fudge            4.0           191
# 11                   Cream Cheese Brownies            4.5           115
# 12               Crispy Rice Cereal Treats            4.0           108
# 13                           Key Lime Bars            4.0            92
# 14                        Classic Brownies            4.5            81
# 15  Chewy, Fudgy Triple Chocolate Brownies            4.0           112
# 16                            S'mores Bars            4.5           196
# 17                  Gooey Butter Cake Bars            4.0            81
# 18                                Blondies            4.0           113
# 19                         Cheesecake Bars            4.5            61
# 20           Easy Chocolate Chunk Brownies            4.0            77
# 21                             Scotcheroos            4.5           139
# 22                            Nanaimo Bars            4.0            36
# 23       Chocolate Ganache-Filled Brownies            4.5            73
# 24                 Raspberry Streusel Bars            4.5            57
# 25                 Quicker Turtle Brownies            4.0             4
# 26                  Gluten-Free Lemon Bars            4.0            13
# 27                              Congo Bars            4.5            36
# 28              Gluten-Free Fudgy Brownies            4.5            24
# 29      Triple-Chocolate Espresso Brownies            4.5            39
# 30                    Crunchy Granola Bars            4.5            36
# 31           Chocolate Peanut Butter Fudge            5.0            30
# 32                       Cast Iron Brownie            4.0            54
# 33                          Basic Brownies            4.5            27
# 34                           Blondie Bites            4.0             7
# 35      Almond-Cherry-Coconut Granola Bars            5.0            10
#
#     Ingredient Count Bake and Prep Time Cool Time
# 0                 21                 1¾         2
# 1                 11                 1¾        1½
# 2                 19                 1¾        1½
# 3                 11                 1½         2
# 4                 13                  1        2½
# 5                 12                 2¾        2½
# 6                 14                 1¼         3
# 7                 11                 1¼         2
# 8                 11                 55         3
# 9                 11                  1        1½
# 10                 7                 45         2
# 11                12                 1¼         2
# 12                 5                 15         1
# 13                11                 1¼         1
# 14                 9                 1¼         2
# 15                 9                  1         2
# 16                 8                 1½         4
# 17                10                 1¾        3½
# 18                 9                 1¼        20
# 19                11                 1¾         2
# 20                11                  1        2½
# 21                 8                  1         2
# 22                16                 40        2½
# 23                12                 1¾        5¼
# 24                10                 1¼         2
# 25                11                 1¼        1½
# 26                12                 1½        2½
# 27                10                 1¼        20
# 28                 9                 1¼        30
# 29                10                  1         2
# 30                 8                 1¾        20
# 31                 8                 40         2
# 32                12                 50        35
# 33                 8                 50         2
# 34                 8                NaN       NaN
# 35                10                 1½        20

# %%
brownie_recipes.dtypes
# Out:
# Title                  object
# Review Rating         float64
# Review Count            Int64
# Ingredient Count        int64
# Bake and Prep Time     object
# Cool Time              object
# dtype: object

# %%
def convert_to_minutes(value):
    if pd.isnull(value):
        return None
    
    value = str(value).strip()
    total = 0.0


    match = re.match(r'^(\d+)?([¼½¾]?)$', value)
    if match:
        whole = match.group(1)
        frac = match.group(2)
        if whole:
            total += int(whole)
        if frac:
            total += fraction_map.get(frac, 0)

            
        if total <= 12:
            return round(total * 60)
        else:
            return round(total)  # Already in minutes?
    
  
    try:
        num = float(value)
        if num <= 12:
            return round(num * 60)
        else:
            return round(num)  # Already in minutes
    except:
        return None
    
brownie_recipes['Bake and Prep Time'] = brownie_recipes['Bake and Prep Time'].apply(convert_to_minutes)
brownie_recipes['Cool Time'] = brownie_recipes['Cool Time'].apply(convert_to_minutes)

# %%
brownie_recipes.dtypes
# Out:
# Title                  object
# Review Rating         float64
# Review Count            Int64
# Ingredient Count        int64
# Bake and Prep Time    float64
# Cool Time             float64
# dtype: object

# %%
brownie_recipes
# Out:
#                                      Title  Review Rating  Review Count  \
# 0                        Ultimate Brookies            4.0            37
# 1                 Millionaire's Shortbread            4.5           842
# 2                 Ultimate Turtle Brownies            4.5            18
# 3                               Lemon Bars            4.5           134
# 4                           Chewy Brownies            4.0           306
# 5               Strawberry Cheesecake Bars            4.5           327
# 6                        Lemon Cookie Bars            4.5           138
# 7                  Browned Butter Blondies            4.0           218
# 8                           Vegan Brownies            4.5            89
# 9                    Ultranutty Pecan Bars            4.5           389
# 10                         Chocolate Fudge            4.0           191
# 11                   Cream Cheese Brownies            4.5           115
# 12               Crispy Rice Cereal Treats            4.0           108
# 13                           Key Lime Bars            4.0            92
# 14                        Classic Brownies            4.5            81
# 15  Chewy, Fudgy Triple Chocolate Brownies            4.0           112
# 16                            S'mores Bars            4.5           196
# 17                  Gooey Butter Cake Bars            4.0            81
# 18                                Blondies            4.0           113
# 19                         Cheesecake Bars            4.5            61
# 20           Easy Chocolate Chunk Brownies            4.0            77
# 21                             Scotcheroos            4.5           139
# 22                            Nanaimo Bars            4.0            36
# 23       Chocolate Ganache-Filled Brownies            4.5            73
# 24                 Raspberry Streusel Bars            4.5            57
# 25                 Quicker Turtle Brownies            4.0             4
# 26                  Gluten-Free Lemon Bars            4.0            13
# 27                              Congo Bars            4.5            36
# 28              Gluten-Free Fudgy Brownies            4.5            24
# 29      Triple-Chocolate Espresso Brownies            4.5            39
# 30                    Crunchy Granola Bars            4.5            36
# 31           Chocolate Peanut Butter Fudge            5.0            30
# 32                       Cast Iron Brownie            4.0            54
# 33                          Basic Brownies            4.5            27
# 34                           Blondie Bites            4.0             7
# 35      Almond-Cherry-Coconut Granola Bars            5.0            10
#
#     Ingredient Count  Bake and Prep Time  Cool Time
# 0                 21               105.0      120.0
# 1                 11               105.0       90.0
# 2                 19               105.0       90.0
# 3                 11                90.0      120.0
# 4                 13                60.0      150.0
# 5                 12               165.0      150.0
# 6                 14                75.0      180.0
# 7                 11                75.0      120.0
# 8                 11                55.0      180.0
# 9                 11                60.0       90.0
# 10                 7                45.0      120.0
# 11                12                75.0      120.0
# 12                 5                15.0       60.0
# 13                11                75.0       60.0
# 14                 9                75.0      120.0
# 15                 9                60.0      120.0
# 16                 8                90.0      240.0
# 17                10               105.0      210.0
# 18                 9                75.0       20.0
# 19                11               105.0      120.0
# 20                11                60.0      150.0
# 21                 8                60.0      120.0
# 22                16                40.0      150.0
# 23                12               105.0      315.0
# 24                10                75.0      120.0
# 25                11                75.0       90.0
# 26                12                90.0      150.0
# 27                10                75.0       20.0
# 28                 9                75.0       30.0
# 29                10                60.0      120.0
# 30                 8               105.0       20.0
# 31                 8                40.0      120.0
# 32                12                50.0       35.0
# 33                 8                50.0      120.0
# 34                 8                 NaN        NaN
# 35                10                90.0       20.0

# %%
brownie_recipes.dropna(inplace=True)
brownie_recipes.reset_index(drop=True, inplace=True)
brownie_recipes
# Out:
#                                      Title  Review Rating  Review Count  \
# 0                        Ultimate Brookies            4.0            37
# 1                 Millionaire's Shortbread            4.5           842
# 2                 Ultimate Turtle Brownies            4.5            18
# 3                               Lemon Bars            4.5           134
# 4                           Chewy Brownies            4.0           306
# 5               Strawberry Cheesecake Bars            4.5           327
# 6                        Lemon Cookie Bars            4.5           138
# 7                  Browned Butter Blondies            4.0           218
# 8                           Vegan Brownies            4.5            89
# 9                    Ultranutty Pecan Bars            4.5           389
# 10                         Chocolate Fudge            4.0           191
# 11                   Cream Cheese Brownies            4.5           115
# 12               Crispy Rice Cereal Treats            4.0           108
# 13                           Key Lime Bars            4.0            92
# 14                        Classic Brownies            4.5            81
# 15  Chewy, Fudgy Triple Chocolate Brownies            4.0           112
# 16                            S'mores Bars            4.5           196
# 17                  Gooey Butter Cake Bars            4.0            81
# 18                                Blondies            4.0           113
# 19                         Cheesecake Bars            4.5            61
# 20           Easy Chocolate Chunk Brownies            4.0            77
# 21                             Scotcheroos            4.5           139
# 22                            Nanaimo Bars            4.0            36
# 23       Chocolate Ganache-Filled Brownies            4.5            73
# 24                 Raspberry Streusel Bars            4.5            57
# 25                 Quicker Turtle Brownies            4.0             4
# 26                  Gluten-Free Lemon Bars            4.0            13
# 27                              Congo Bars            4.5            36
# 28              Gluten-Free Fudgy Brownies            4.5            24
# 29      Triple-Chocolate Espresso Brownies            4.5            39
# 30                    Crunchy Granola Bars            4.5            36
# 31           Chocolate Peanut Butter Fudge            5.0            30
# 32                       Cast Iron Brownie            4.0            54
# 33                          Basic Brownies            4.5            27
# 34      Almond-Cherry-Coconut Granola Bars            5.0            10
#
#     Ingredient Count  Bake and Prep Time  Cool Time
# 0                 21               105.0      120.0
# 1                 11               105.0       90.0
# 2                 19               105.0       90.0
# 3                 11                90.0      120.0
# 4                 13                60.0      150.0
# 5                 12               165.0      150.0
# 6                 14                75.0      180.0
# 7                 11                75.0      120.0
# 8                 11                55.0      180.0
# 9                 11                60.0       90.0
# 10                 7                45.0      120.0
# 11                12                75.0      120.0
# 12                 5                15.0       60.0
# 13                11                75.0       60.0
# 14                 9                75.0      120.0
# 15                 9                60.0      120.0
# 16                 8                90.0      240.0
# 17                10               105.0      210.0
# 18                 9                75.0       20.0
# 19                11               105.0      120.0
# 20                11                60.0      150.0
# 21                 8                60.0      120.0
# 22                16                40.0      150.0
# 23                12               105.0      315.0
# 24                10                75.0      120.0
# 25                11                75.0       90.0
# 26                12                90.0      150.0
# 27                10                75.0       20.0
# 28                 9                75.0       30.0
# 29                10                60.0      120.0
# 30                 8               105.0       20.0
# 31                 8                40.0      120.0
# 32                12                50.0       35.0
# 33                 8                50.0      120.0
# 34                10                90.0       20.0

# %%
brownie_recipes.to_csv('brownie_recipes.csv', index=False)
